# %% [markdown]
# # Forget Occupy Wall Street! #
# ## Aliens Occupy Earth in the 31st century##
#
# The year is 3045, and you are one of the rare harmonious humans that descended from the "Earthers," who remained on this planet following the Dual Exodus of Muskovites and Bezosovians.
#
# ![alien_contact.jpg](attachment:alien_contact.jpg)
# Your target goal is to PREDICT WHEN TO INITIATE MEDITATION for tracking the aliens. We want to know "TARGET_INIT_MEDITATE"
# We have data from different UFOs, and our electromagneto-spiritual engineers identified that these UFOs come in 3 different types. NUC, for Nuclear Powered, PSY, for Psychic Level 1, and PSY_B, for Psychic Human Hybrids.
#
# The UFOS operate in the following manner. Through meditation, we can harvest "Source" energy for the UFOs to travel from Earth to any new point in the Universe.

# %%
import pandas as pd 
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

df = pd.read_csv('ALIENS_conv.csv')

print(df)
# Out:
#      energetic_convergences  energy_consumed  UFO_Label  max_spiritual_size  \
# 0           R1SSM11R_2_N001            0.847          1                 7.7
# 1           R1SSM11R_2_N001            0.231          1                 7.7
# 2           R1SSM11R_2_N001            6.622          1                 7.7
# 3           R1SSM11R_2_N001            4.774          1                 7.7
# 4           R1SSM11R_2_N001            0.000          1                 7.7
# ...                     ...              ...        ...                 ...
# 2114         DALYCTY_1_N016            3.984         16                33.2
# 2115         DALYCTY_1_N016            4.316         16                33.2
# 2116         DALYCTY_1_N016            7.968         16                33.2
# 2117         DALYCTY_1_N016            5.644         16                33.2
# 2118         DALYCTY_1_N016            8.632         16                33.2
#
# ...
